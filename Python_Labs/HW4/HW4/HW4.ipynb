# %% [markdown]
# # Домашнее задание 2
# ## часть 2

# %%
last_name = 'ФАМИЛИЯ'
g = 'ГРУППА' #ИУ3-51
student_id = '16У001'

# %% [markdown]
# ### Задание 1
#
# - Определить основные параметры выборки, заданной вариантом
# - Построить гистограмму по количеству
# - Нормировать гистограмму, отметить на этом графике эмпирическую и теоретическую (выбрать предполагаемое теоретическое распределение по построенным графикам) функцию плотности вероятности (PDF)
# - Построить на одном полотне эмпирическую и теоретическую функции распределения (CDF)
# - Вывести таблицу (или представить в каком-либо другом виде) вычисленных значений для каждой полосы гистограммы (диапазон интервала, середина, количество попаданий, эмпирическое и теоретическое значение PDF в середине столбца, эмпирическое и теоретическое значение CDF в середине столбца)
# - Проверить гипотезы о подчинении выборки теоретическому закону по критерию $\chi^2$ и критерию Колмогорова-Смирнова (эти тесты реализованы в модуле `scipy.stats`). Описать полученные результаты

# %%
# Пример вывода без проверки по критериям.
# Out:
#        bin_range  c_e     pdf_e    mid     pdf_t   c_t  cdf_e     cdf_t
# b0    [0.0; 3.1)   97  0.156452   1.55  0.143319  89.0  0.185  0.259038
# b1    [3.1; 6.2)   50  0.080645   4.65  0.078686  49.0  0.675  0.593194
# b2    [6.2; 9.3)   20  0.032258   7.75  0.043200  27.0  0.810  0.776654
# b3   [9.3; 12.4)   17  0.027419  10.85  0.023718  15.0  0.920  0.877378
# b4  [12.4; 15.5)    9  0.014516  13.95  0.013022   8.0  0.965  0.932677
# b5  [15.5; 18.6)    3  0.004839  17.05  0.007149   4.0  0.980  0.963038
# b6  [18.6; 21.7)    0  0.000000  20.15  0.003925   2.0  0.980  0.979707
# b7  [21.7; 24.8)    2  0.003226  23.25  0.002155   1.0  0.995  0.988859
# b8  [24.8; 27.9)    1  0.001613  26.35  0.001183   1.0  0.995  0.993883
# b9  [27.9; 31.0]    1  0.001613  29.45  0.000650   0.0  1.000  0.996642

# %% [markdown]
# Как взять свой вариант

# %%
import pandas as pd
df = pd.read_csv('task1.csv')
x = df[df['ФИО'].str.contains('Бехбудов')].drop(['ФИО', 'Группа'], axis=1).values

# %% [markdown]
# ### Задание 2
#
# - сгенерировать независимую переменную как `x = np.linspace(1,20,200)` (зависимая переменная задана вариантом)
# - восстановить зависимость с помощью регрессионных моделей $f(x) = ax+b$ и $f(x) = ax^2 + bx + c$
# - выбрать какая модель лучше описывает зависимость (сравнить суммы квадратов регрессионных остатков)
# - графически изобразить полученные результаты

# %%
# Пример вывода
# Out:
# f1: a = -66.9727 b = 1121.0234
# SSE1: 3457267.68
# f2: a = 4.5581 b = -162.6937 c = 1485.056348
# SSE2: 388238.07

# %% [markdown]
# Как взять свой вариант

# %%
import pandas as pd
df = pd.read_csv('task2.csv')
y = df[df['ФИО'].str.contains('Бехбудов')].drop(['ФИО', 'Группа'], axis=1).values
